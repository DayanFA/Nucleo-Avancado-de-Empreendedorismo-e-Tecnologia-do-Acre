# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork20235326-2022-01-01" target="_blank">
#     <img src="https://www.ufac.br/nave/imagens/logo.png/@@images/b79444d1-a803-4e49-b5da-98228cf1e2fd.png" width="200" alt="Nave Tech Logo"/>
#     </a>
# </p>
#
#
# # Desenvolvimento do modelo
#
#
# ## Objetivo
#
# Após completar este lab, você sera capaz de:
#
# *   Desenvolver um modelo de regressão linear para previsão de preços de carros

# %% [markdown]
# <p>Nesta aula, nós desenvolveremos diversos modelos que preverão o preço do carro usando as variáveis ou features. Isto é apenas uma estimativa, mas deve nos dar uma ideia objetiva do quanto o carro deve custar.</p>

# %% [markdown]
# Algumas perguntas que queremos fazer nesta aula e que o modelo desenvolvido vai nos ajudar a respondê-las:
# <ul>
#     <li>Eu sei se o revendedor da agencia está oferecendo um valor justo em troca?</li>
#     <li>Eu sei que coloquei um valor justo no meu carro?</li>
# </ul>
# <p>Em análise de dados, nós frequentemente usamos <b>Desenvolvimento do Modelo</b> para nos ajudar a prever observações futuras a partir dos dados que temos.</p>
#
# <p>Um modelo nos ajudará a entender a relação exata entre diferentes variáveis ​​e como essas variáveis ​​são usadas para prever o resultado.</p>

# %% [markdown]
# <h4>Setup</h4>

# %% [markdown]
# Import libraries:

# %%
#install specific version of libraries used in lab
#! mamba install pandas==1.3.3-y
#! mamba install numpy=1.21.2-y
#! mamba install sklearn=0.20.1-y

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Carrega os dados do drive e armazená-los no dataframe `df`:

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# path of data 
path = '/content/drive/MyDrive/Colab Notebooks/NaveTech/aula4 - 08-12-2022/auto_cleaned.csv'
df = pd.read_csv(path)
df.head()

# %% [markdown]
# <h2>1. Regressão linear e Regressão Linear e Regressão Linear Múltipla</h2>

# %% [markdown]
# <h4>Regressão Linear</h4>

# %% [markdown]
# <p>Um exemplo de um Modelo de Dados que usaremos é:</p>
# <b>Regressão Linear Simples</b>
#
# <br>
# <p>Regressão Linear Simples é um método que ajuda-nos a entender a relação entre duas variáveis:</p>
# <ul>
#     <li>O preditor/variável independente (X)</li>
#     <li>A resposta/variável dependente (que queremos prever) (Y)</li>
# </ul>
#
# <p>O resultado da Regressão Linear é uma <b>função linear</b> que prever a resposta (variável dependente) como uma função da variável preditora (variável independente).</p>

# %% [markdown]
# $$
# Y: Variavel\ Dependente \\\\
# X: Variavel\ Independente
# $$

# %% [markdown]
# <b>Função linear</b>
# $$
# \hat{Y} = a + b  X
# $$

# %% [markdown]
# <ul>
#     <li>a refere-se a <b>intercepção</b> da regressão linear, em outras palavras: o valor de Y quando X é 0</li>
#     <li>b refere-se a <b>inclinação</b> da regressão linear, em outras palavras: o valor com que Y muda quando X aumenta em 1 unidade.</li>
# </ul>

# %% [markdown]
# <h4>Vamos carregar os módulos para regressão linear:</h4>

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# <h4>Crie o objeto regressão linear:</h4>

# %%
lm = LinearRegression()
lm

# %% [markdown]
# <h4>Como "highway-mpg" poderia nos ajudar a prever o preço do carro?</h4>

# %% [markdown]
# Vamos ver como 'highway-mpg' pode nos ajudar prever o preço do carro.
# Usando regressão linear simples, queremos criar uma função linear com "highway-mpg" como variável preditora e "price" como variável de resposta.

# %%
X = df[['highway-mpg']]
Y = df['price']

# %% [markdown]
# Ajuste (Fit) o modelo linear usando highway-mpg:

# %%
lm.fit(X,Y)

# %% [markdown]
# Podemos realizar uma previsão:

# %%
Yhat=lm.predict(X)
Yhat[0:5]

# %% [markdown]
# <h4>Qual é o valor da intercepção (a)?</h4>

# %%
lm.intercept_

# %% [markdown]
# <h4>Qual é o valor da inclinação (b)?</h4>

# %%
lm.coef_

# %% [markdown]
# <h3>Qual é o modelo linear estimado final que obtemos?</h3>

# %% [markdown]
# Devemos obter um modelo linear final com a estrutura:

# %% [markdown]
# $$
# \hat{Y} = a + b  X
# $$

# %% [markdown]
# Substituindo os valores atuais que obtemos na equação, fica:

# %% [markdown]
# <b>Price</b> = 38423.31 - 821.73 x <b>highway-mpg</b>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Questão #1 a): </h1>
#
# <b>Crie um objeto regressão linear chamado "lm1".</b>
#
# </div>

# %%
# Escreva seu codigo abaixo e pressione Shift+Enter para executar

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# lm1 = LinearRegression()
# lm1
# ```
#
# </details>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Questão #1 b): </h1>
#
# <b>Ajuste o modelo usando "engine-size" como variável independente e "price" como variável dependente</b>
#
# </div>

# %%
# Escreva seu codigo abaixo e pressione Shift+Enter para executar

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# lm1.fit(df[['engine-size']], df[['price']])
# lm1
# ```
#
# </details>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Questão #1 c):</h1>
#
# <b>Encontre a inclinação (b) e a interceptação (a).</b>
#
# </div>

# %% [markdown]
# <h4>Inclinação</h4>

# %%
# Escreva seu codigo abaixo e pressione Shift+Enter para executar

# %% [markdown]
# <h4>Intercept</h4>

# %%
# Escreva seu codigo abaixo e pressione Shift+Enter para executar

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# # Slope
# lm1.coef_
#
# # Intercept
# lm1.intercept_
# ```
#
# </details>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Questão #1 d): </h1>
#
# <b>Qual é a equação da reta prevista? Você pode usar x e yhat ou "engine-size" ou "price".</b>
#
# </div>

# %%
# Escreva seu codigo abaixo e pressione Shift+Enter para executar

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# # using X and Y
# Yhat=-7963.34 + 166.86*X
#
# Price=-7963.34 + 166.86*engine-size
#
# ```
#
# </details>

# %% [markdown]
# <h4>Regressão Linear Múltipla</h4>

# %% [markdown]
# <p>E se quisermos prever o preço do carro usando mais de uma variável?</p>
#
# <p>Podemos usar <b>Regressão Linear Múltipla</b>.
# A regressão linear múltipla é muito semelhante à regressão linear simples, mas esse método é usado para explicar a relação entre uma variável de resposta contínua (dependente) e <b>duas ou mais</b> variáveis ​​preditoras (independentes).
# A maioria dos modelos de regressão do mundo real envolve vários preditores. Ilustraremos a estrutura usando quatro variáveis ​​preditoras, mas esses resultados podem ser generalizados para qualquer número inteiro:</p>

# %% [markdown]
# $$
# Y: Variavel \ de \ Resposta\\\\
# X\_1 :Variavel\ Preditora \ 1\\\\
# X\_2: Variavel\ Preditora \ 2\\\\
# X\_3: Variavel\ Preditora \ 3\\\\
# X\_4: Variavel\ Preditora \ 4\\\\
# $$

# %% [markdown]
# $$
# a: intercepcao\\\\
# b\_1 :coeficiente \ da\ Variavel \ 1\\\\
# b\_2: coeficiente \ da\ Variavel \ 2\\\\
# b\_3: coeficiente \ da\ Variavel \ 3\\\\
# b\_4: coeficiente \ da\ Variavel \ 4\\\\
# $$

# %% [markdown]
# A equação é dada por:

# %% [markdown]
# $$
# \hat{Y} = a + b\_1 X\_1 + b\_2 X\_2 + b\_3 X\_3 + b\_4 X\_4
# $$

# %% [markdown]
# <p>Da aula 3, sabemos que outros bons preditores de preço podem serem:</p>
# <ul>
#     <li>Horsepower</li>
#     <li>Curb-weight</li>
#     <li>Engine-size</li>
#     <li>Highway-mpg</li>
# </ul>
# Vamos desenvolver um modelo usando essas variáveis como variáveis preditoras.

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %% [markdown]
# Ajustar o modelo linear usando as quatros variáveis mencionadas acima.

# %%
lm.fit(Z, df['price'])

# %% [markdown]
# Qual é o valor da intercepção (a)?

# %%
lm.intercept_

# %% [markdown]
# Quais são os valores dos coeficientes (b1, b2, b3, b4)?

# %%
lm.coef_

# %% [markdown]
# Qual é o modelo estimado final que obtemos?

# %% [markdown]
# Como visto acima, devemos obter uma função linear final com a estrutura:
#
# $$
# \hat{Y} = a + b\_1 X\_1 + b\_2 X\_2 + b\_3 X\_3 + b\_4 X\_4
# $$
#
# Qual é a função linear obtida neste exemplo?

# %% [markdown]
# <b>Price</b> = -15678.742628061467 + 52.65851272 x <b>horsepower</b> + 4.69878948 x <b>curb-weight</b> + 81.95906216 x <b>engine-size</b> + 33.58258185 x <b>highway-mpg</b>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1> Questão  #2 a): </h1>
# Crie e treine (ajuste) um modelo Regressão Linear Múltipla "lm2" onde a variável resposta é "price", e as variáveis preditoras são "normalized-losses" e "highway-mpg".
# </div>

# %%
# Escreva seu codigo abaixo e pressione Shift+Enter para executar

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# lm2 = LinearRegression()
# lm2.fit(df[['normalized-losses' , 'highway-mpg']],df['price'])
#
#
# ```
#
# </details>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Questião  #2 b): </h1>
# <b>Encontre o coeficiente do modelo.</b>
# </div>

# %%
# Escreva seu codigo abaixo e pressione Shift+Enter para executar

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# lm2.coef_
#
# ```
#
# </details>

# %% [markdown]
# <h2>2. Avaliação do Modelo usando Visualização</h2>

# %% [markdown]
# Agora que desenvolvemos alguns modelos, como avaliamos nossos modelos e escolhemos o melhor? Uma maneira de fazer isso é usando uma visualização.

# %% [markdown]
# Importar o pacote seaborn:

# %%
# import the visualization package: seaborn
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <h3>Plotar Gráfico de Regressão</h3>

# %% [markdown]
# <p>Quando se trata de regressão linear simples, uma excelente maneira de visualizar o ajuste do nosso modelo é usando <b>gráficos de regressão</b>.</p>
#
# <p>Este gráfico mostrará uma combinação de pontos de dados dispersos (um <b>gráfico de dispersão</b>), bem como a linha de <b>regressão linear</b> ajustada passando pelos dados. Isso nos dará uma estimativa razoável da relação entre as duas variáveis, a força da correlação, bem como a direção (correlação positiva ou negativa).</p>

# %% [markdown]
# Vamos visualizar **highway-mpg** como variável preditora potencial do preço:

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)

# %% [markdown]
# <p>Conforme visto na aula 3, este plot mostra que price é negativamente correlacionada a highway-mg pois a inclinação (b) da regressão é negativa.
#
# Uma coisa a ter em mente ao olhar para um gráfico de regressão é prestar atenção em como os pontos de dados estão dispersos em torno da linha de regressão. Isso lhe dará uma boa indicação da variância dos dados e se um modelo linear seria o melhor ajuste ou não. Se os dados estiverem muito distantes da linha, esse modelo linear pode não ser o melhor modelo para esses dados.
#
# Vamos comparar este gráfico ao plot da regressão de "peak-rpm".</p>

# %%
plt.figure(figsize=(width, height))
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)

# %% [markdown]
# <p>Comparando o gráfico de regressão de "peak-rpm" e "highway-mpg", vemos que os pontos de "highway-mpg" estão muito mais próximos da linha gerada e, em média, diminuem. Os pontos de "peak-rpm" estão mais espalhados em torno da linha prevista e é muito mais difícil determinar se os pontos estão diminuindo ou aumentando à medida que o "peak-rpm" aumenta.</p>

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Questão #3:</h1>
# <b>Dado a regressão plotada acima, "peak-rpm" ou "highway-mpg" é mais fortemente correlacionada com "price"? Use o método ".corr()" para verificar sua resposta.</b>
# </div>

# %%
# Escreva seu codigo abaixo e pressione Shift+Enter para executar-lo

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# # The variable "highway-mpg" has a stronger correlation with "price", it is approximate -0.704692  compared to "peak-rpm" which is approximate -0.101616. You can verify it using the following command:
#
# df[["peak-rpm","highway-mpg","price"]].corr()
#
# ```
#
# </details>

# %% [markdown]
# <h3>Plot Residual</h3>
#
# <p>Um bom jeito de visualizar a variância dos dados é usar um plot residual.</p>
#
# <p>O que é <b>residual</b>?</p>
#
# <p>A diferença entre o valor observado (y) e o valor predito (Yhat) é chamado residual (e). Quando olhamos no plot da regressão, o residual é a distância do ponto dos dados a linha até a linha de regressão ajustada.</p>
#
# <p>Então o que é um <b>plot residual</b>?</p>
#
# <p>Um plot residual é um gráfico que mostra os resíduos no eixo y vertical e a variável independente no eixo x horizontal.</p>
#
# <p>O que precisamos prestar atenção quando olhamos um plot residual?</p>
#
# <p>Nós olhamos para distribuição dos resíduos:</p>
#
# <p>- Se os pontos em um gráfico residual estiverem <b>distribuídos aleatoriamente em torno do eixo x</b>, então um <b>modelo linear é apropriado</b> para os dados.
#
#
# Por que isto acontece? Resíduos distribuídos aleatoriamente significam que a variância é constante e, portanto, o modelo linear é um bom ajuste para esses dados.</p>

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.residplot(x=df['highway-mpg'], y=df['price'])
plt.show()

# %% [markdown]
# <i>O que este plot está nos dizendo então?</i>
#
# <p>Podemos ver a partir deste gráfico residual que os resíduos não estão espalhados aleatoriamente ao redor do eixo x, levando-nos a acreditar que talvez um modelo não linear seja mais apropriado para esses dados.</p>

# %% [markdown]
# <h3>Regressão Linear Múltipla</h3>

# %% [markdown]
# <p>Como visualizamos um modelo de regressão linear múltipla? Isso fica um pouco mais complicado porque você não pode visualizá-lo com regressão ou gráfico residual.</p>
#
# <p>Uma maneira de observar o ajuste do modelo é observando o <b>gráfico de distribuição</b>. Podemos observar a distribuição dos valores ajustados resultantes do modelo e compará-la com a distribuição dos valores reais.</p>

# %% [markdown]
# Primeiro, vamos fazer uma previsão:

# %%
Y_hat = lm.predict(Z)

# %%
plt.figure(figsize=(width, height))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y_hat, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()

# %% [markdown]
# <p>Podemos ver que os valores ajustados estão razoavelmente próximos dos valores reais, pois as duas distribuições se sobrepõem um pouco. No entanto, definitivamente há espaço para melhorias.</p>

# %% [markdown]
# <h2>4. Métricas para Avaliação na Amostra de dados</h2>

# %% [markdown]
# <p>Quando avaliamos nossos modelos de previsão, não somente queremos visualizar os resultados, mas também queremos medir o quantitativo para determinar o quão preciso é o modelo.</p>
#
# <p>Duas importantes métricas que são frequentemente usadas em Estatística e Ciência de Dados para determinar a precisão de um modelo são:</p>
# <ul>
#     <li><b>R^2 / R-squared</b></li>
#     <li><b>Mean Squared Error (MSE)</b></li>
# </ul>
#
# <b>R-squared</b>
#
# <p>R squared, também conhecido por coeficiente de determinação, é uma medida para indicar o quão perto os dados está da linha de regressão ajustada.</p>
#
# <p>O valor de R-squared é o percentual da variação da variável de resposta (y) que é explicado pelo modelo linear.</p>
#
# <b>Mean Squared Error (MSE)</b>
#
# <p>The Mean Squared Error mede a média dos quadrados dos erros. Isto é, a diferença entre o valor real (y) e o valor estimado (ŷ).</p>

# %% [markdown]
# <h3>Modelo 1: Regressão Linear Simples (Simple Linear Regression - SLR)</h3>

# %% [markdown]
# Vamos calcular o R^2:

# %%
#highway_mpg_fit
lm.fit(X, Y)
# Find the R^2
print('The R-square is: ', lm.score(X, Y))

# %% [markdown]
# Dizemos que \~49.659% da variação do price é explicado por este simples modelo linear "highway_mpg_fit".

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Questão #4:</h1>
# <b>Vamos criar um novo modelo SLR e avalie o seu desempenho em termos de R-squared usando como feature "horsepower" H e alvo Y. Compare o desempenho obtido com o desempenho do modelo ajustado para "highway-mpg".</b>
# </div>

# %%
# Escreva seu codigo abaixo e pressione Shift+Enter para executa-lo

# %%
lm3 = LinearRegression()

# %%
H = df[["horsepower"]]

# %%
#horsepower_fit
lm3.fit(H, Y)
# Find the R^2
print('The R-square is: ', lm3.score(H, Y))

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# lm3 = LinearRegression()
# H = df[["horsepower"]]
#
# lm3.fit(X, Y)
# print('The R-square is: ', lm3.score(H, Y))
#
# ```
#
# </details>

# %% [markdown]
# Vamos calcular o MSE:

# %% [markdown]
# Podemos prever a saída e apresentar o resultado para alguns exemplos fornecidos, ou seja "yhat" usando o método de predição, onde X é a variável de entrada:

# %%
Yhat=lm.predict(X)
print('The output of the first four predicted value is: ', Yhat[0:4])

# %% [markdown]
# Vamos importar a função <b>mean_squared_error</b> do módulo <b>metrics</b> do <b>sklearn</b>:

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# Podemos comparar os preços preditos com os preços reais:

# %%
mse = mean_squared_error(df['price'], Yhat)
print('The mean square error of price and predicted value is: ', mse)

# %% [markdown]
# <div class="alert alert-danger alertdanger" style="margin-top: 20px">
# <h1>Questão #5:</h1>
# <b>Avalie o MSE do modelo SLR treinado com a feature "horsepower". Compare o desempenho obtido com o desempenho do modelo ajustado para "highway-mpg".</b>
# </div>

# %%
# Escreva seu codigo abaixo e pressione Shift+Enter para executa-lo

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# Yhat3 = lm3.predict(H)
#
# mse3 = mean_squared_error(df['price'], Yhat3)
# print('The output of the first four predicted value is: ', Yhat3[0:4])
#
# ```
#
# </details>

# %% [markdown]
# <h3>Modelo 2: Regressão Linear Múltipla (MLR - Multiple Linear Regression)</h3>

# %% [markdown]
# Vamos calcular o R^2:

# %%
# fit the model 
lm.fit(Z, df['price'])
# Find the R^2
print('The R-square is: ', lm.score(Z, df['price']))

# %% [markdown]
# Dizemos que \~80.896 % da variação do price é explicada por este modelo de regressão linear múltipla "multi_fit".

# %% [markdown]
# Vamos calcular o MSE.

# %% [markdown]
# Produzimos a seguinte previsão:

# %%
Y_predict_multifit = lm.predict(Z)

# %% [markdown]
# Comparamos os resultados dos preços preditos com os preços reais dos dados:

# %%
print('The mean square error of price and predicted value using multifit is: ', \
      mean_squared_error(df['price'], Y_predict_multifit))

# %% [markdown]
# <h2>5. Previsão e Tomada de Decisão</h2>
# <h3>Previsão</h3>
#
# <p>Na seção anterior, treinamos o modelo usando o método <b>fit</b>. Agora usaremos o método <b>predict</b> para produzir uma previsão. Vamos importar <b>pyplot</b> para plotagem; também usaremos algumas funções do numpy.</p>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# Cria uma nova entrada com dados para testar o modelo:

# %%
new_input=np.arange(1, 100, 1).reshape(-1, 1)

# %%
new_input

# %% [markdown]
# Treinar o modelo:

# %%
lm.fit(X, Y)
lm

# %% [markdown]
# Produzir uma previsão:

# %%
yhat=lm.predict(new_input)
yhat[0:5]

# %% [markdown]
# Podemos plotar os dados:

# %%
plt.plot(new_input, yhat)
plt.show()

# %% [markdown]
# ### Obrigado por ter completado este lab!
#
# ### Créditos
#
# Este notebook foi completamente revisado e foi adaptado a partir do material do curso da IBM no Coursera: *Data Analysis with Python* por Joseph Santarcangelo, Ph.D
