# %% [markdown]
# #Curso 2 Empreendedorismo e tecnologias avançadas
#
# ##Módulo: Tecnologias Avançadas

# %% [markdown]
# ###Análise de dados com Inteligência Artificial (20h)
# Ementa: *Introdução a Análise de Dados; Produção de Dados; Armazenamento Analítico; Análise de Dados; Problemas e Soluções em Análise de Dados; Análise de Dados Categóricos; Exemplos de Dados: Métricas de Desempenho; Indicadores; Sistemas de Medição. Módulos Python para Análise de Dados. Introdução à Análise de Dados com Python. Análise exploratória de Dados; Aplicações de modelos e algoritmos de aprendizado de máquina.* <br>
#
# Para mais informações, consulte: https://www.ufac.br/nave/menu/cursos
#
#
#
# ---
#
#
# <i>Prof. Raoni Simões Ferreira</i>

# %% [markdown]
# #Conteúdo programático
#
# *   Começando com Pandas
# *   Técnicas de preparação dos dados para análise
# *   Visualização dos dados
# *   Seleção e avaliação de um modelo de regressão linear
# *   Hands-on: Laboratório de Análise de Dados

# %% [markdown]
# #Referências
#
#
#
# 1.   Pandas. Getting started tutorials. 2022. Disponível em <https://pandas.pydata.org/docs/getting_started/intro_tutorials/index.html>
# 2.   Molin, Stefanie. Pandas Workshop - Introduction to data analysis using Pandas. 2022. Disponível em <https://github.com/stefmolin/pandas-workshop>
# 3.   Géron, Aurélien. Mãos à Obra: Aprendizado de Máquina com Scikit-Learn & TensorFlow. Alta Books. 2019

# %% [markdown]
# Um exemplo de programa em Python

# %%
print("Hello World!") #print de um hello world
# Out:
# Hello World!

# %%
a = 6
b = 4
print(a * b)
# Out:
# 24

# %%
if a > 0:
  print("a = ",a)
else:
  print("a eh menor que 0")
# Out:
# a 6
